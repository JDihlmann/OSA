# %% [markdown]
# # Avatar Dataset Loader Tests

# %% [markdown]
# #### Import Statements

# %%
# %%capture
import os, sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from dataset.loader.avatarDatasetLoader import AvatarDatasetLoader

# %% [markdown]
# #### Load Dataset

# %%
dl = AvatarDatasetLoader()
dl.load_data()
# Out:
# Metal device set to: Apple M1 Max
#
# systemMemory: 32.00 GB
# maxCacheSize: 10.67 GB
# 2022-08-12 13:09:58.737189: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-08-12 13:09:58.737570: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# #### Plot Batch of Data

# %%
# Take 100 batches of 256 points near
idx_points, points, sdfs, colors, normals = dl.get_batch("Female_Adult_01", "near", take_size=100)
dl.plot_avatar_points_color(points, colors)
dl.plot_avatar_points_normals(points, sdfs, normals)

# Take 100 batches of 256 points far
idx_points, points, sdfs, colors, normals = dl.get_batch("Female_Adult_01", "far", take_size=100)
dl.plot_avatar_points_color(points, colors)
dl.plot_avatar_points_sdf(points, sdfs)
dl.plot_avatar_points_sdf(points, sdfs, outside=False)
dl.plot_avatar_points_normals(points, sdfs, normals)

# %% [markdown]
# #### Plot Avatar, Points and SDFs

# %%
print("Avatar")
dl.plot_avatar("Adults", "Male_Adult_04")

points, sdfs, colors, normals = dl.get_points("Male_Adult_04", "near")
print(normals)

print("Point Cloud Color")
dl.plot_avatar_points_color(points, colors)
print("SDF points outside")
dl.plot_avatar_points_sdf(points, sdfs, outside=True)
print("SDF points inside")
dl.plot_avatar_points_sdf(points, sdfs, outside=False)
print("Normals ")
dl.plot_avatar_points_normals(points, sdfs, normals)
# Out:
# concatenating texture: may result in visual artifacts
# Avatar
# [[ 0.63916654 -0.08234661  0.76464709]
#  [ 0.7408599   0.23627424 -0.62872975]
#  [-0.99316999  0.00402093 -0.116607  ]
#  ...
#  [-0.36598576  0.23218452  0.90119075]
#  [-0.05877925  0.40361753 -0.91303772]
#  [-0.47551102 -0.86962827  0.13280038]]
# Point Cloud Color
# SDF points outside
# SDF points inside
# Normals

# %%
print("Avatar")
dl.plot_avatar("Professions", "Business_Female_04")

points, sdfs, colors, normals = dl.get_points("Business_Female_04", "near")
print(sdfs)

print("Point Cloud Color")
dl.plot_avatar_points_color(points, colors)
print("Point Cloud Color surface projection")
dl.plot_avatar_points_color(dl.map_points_to_surface(points, sdfs, normals), colors)
print("SDF points outside")
dl.plot_avatar_points_sdf(points, sdfs, outside=True)
print("SDF points inside")
dl.plot_avatar_points_sdf(points, sdfs, outside=False)
print("Normals ")
dl.plot_avatar_points_normals(points, sdfs, normals)
# Out:
# concatenating texture: may result in visual artifacts
# Avatar
# [5.5820295e-09 2.2850232e-08 3.3766963e-09 ... 1.2501898e-08 1.9164730e-08
#  9.9613420e-09]
# Point Cloud Color
# Point Cloud Color surface projection
# SDF points outside
# SDF points inside
# Normals

# %% [markdown]
# #### Coordinate System Check

# %%
import numpy as np

colors = np.zeros((512,3))

print("x axis [0,1]")
points = np.zeros((512,3))
points[:,0] = np.random.rand(512)
dl.plot_avatar_points_color(points, colors)

print("y axis [0,1]")
points = np.zeros((512,3))
points[:,1] = np.random.rand(512)
dl.plot_avatar_points_color(points, colors)
# Out:
# x axis [0,1]
# y axis [0,1]
