# %% [markdown]
# # Image Dataset Loader Tests

# %% [markdown]
# #### Import Statements

# %%
# %%capture
import os, sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from dataset.loader.imageDatasetLoader import ImageDatasetLoader

# %% [markdown]
# #### Load Dataset

# %%
dl = ImageDatasetLoader()
dl.load_data()
# Out:
# Metal device set to: Apple M1 Max
#
# systemMemory: 32.00 GB
# maxCacheSize: 10.67 GB
# 2022-08-12 13:11:01.323425: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-08-12 13:11:01.323571: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# #### Plot Batch of Data

# %%
print("Training Data")
dl.plot_batch(dl.train_ds)

print("Validation Data")
dl.plot_batch(dl.val_ds)
# Out:
# Training Data
# 2022-08-12 13:11:04.060249: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Validation Data

# %% [markdown]
# #### Plot Image and Information

# %%
dl.plot_image("home_0", "Male_Adult_16")
dl.pretty_print_image_info("home_0", "Male_Adult_16")
# Out:
# Avatar Name:  Male_Adult_16
# Environment Name:  home_0
# ----------------------------------------------------------------------------------------------------------
# HDR:  neon_photostudio_2k.hdr
# ----------------------------------------------------------------------------------------------------------
# Avatar Position:  {'x': -0.04521827592725341, 'y': -0.0237393453458993}
# Avatar Rotation:  {'z': -89.9458422897516}
# Avatar Bone:  {'x': -1.7152271846786258, 'y': -0.7808810676440805, 'z': -3.8206107691124602}
# ----------------------------------------------------------------------------------------------------------
# Camera Position:  {'x': -0.09908494420163526, 'y': -3.3412070933066547, 'z': 1.5446771191636601}
# Camera Target:  {'x': 0.008261060828838596, 'z': 0.9028170515200156}

# %%
dl.plot_image("research_0", "Female_Adult_04")
dl.pretty_print_image_info("research_0", "Female_Adult_04")
# Out:
# Avatar Name:  Female_Adult_04
# Environment Name:  research_0
# ----------------------------------------------------------------------------------------------------------
# HDR:  christmas_photo_studio_01_2k (1).hdr
# ----------------------------------------------------------------------------------------------------------
# Avatar Position:  {'x': 0.007139879194614382, 'y': 0.031223777585172682}
# Avatar Rotation:  {'z': -85.44021264838109}
# Avatar Bone:  {'x': 0.8969398401281303, 'y': -2.147202359655579, 'z': -0.42742043669502205}
# ----------------------------------------------------------------------------------------------------------
# Camera Position:  {'x': -0.03246012984531431, 'y': -3.0435612745574354, 'z': 1.4376790843933283}
# Camera Target:  {'x': 0.04164863622846002, 'z': 0.9029707586342413}
